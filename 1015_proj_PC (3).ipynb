# %%
! pip install pandas
! pip install fake_useragent 
! pip install tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\luake\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\luake\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\luake\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\luake\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\luake\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: fake_useragent in c:\users\luake\appdata\roaming\python\python39\site-packages (0.1.11)
# Requirement already satisfied: tqdm in c:\users\luake\anaconda3\lib\site-packages (4.62.3)
# Requirement already satisfied: colorama in c:\users\luake\anaconda3\lib\site-packages (from tqdm) (0.4.4)

# %%
import requests
import pandas as pd
import time as time
from datetime import datetime
from fake_useragent import UserAgent
from tqdm import tqdm
import os
import math

# %%
def read_html_thing():
    df1 = pd.DataFrame()
    
    urlBase = 'https://twitchtracker.com/channels/ranking?page='
    
    ua = UserAgent()
    
    header = {
      "User-Agent": ua.random,
      "X-Requested-With": "XMLHttpRequest"
    }
    
    try:
        for page in range(76, 200):
            url = urlBase + str(page)
            time.sleep(1)

            r = requests.get(url, headers=header)

            dfs = pd.read_html(r.text)
            unclean = dfs[0]

            df2 = pd.DataFrame()

            df2['Name'] = list(filter(lambda x: '.ads ' not in x, unclean['Unnamed: 2'].to_list()))
            df2['Avg Viewers'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['AVG Viewers'].to_list()))))
            df2['Time Streamed'] = list(map(float, list(map(lambda x: x.replace('hours', ''), list(filter(lambda x: '.ads ' not in x, unclean['Time Streamed'].to_list()))))))
            df2['All Time Peak Viewers'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['All Time Peak Viewers'].to_list()))))
            df2['Hours Watched'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['Hours Watched'].to_list()))))
            df2['Rank'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['Rank'].to_list()))))
            df2['Followers Gained'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['Followers Gained'].to_list()))))
            df2['Total Followers'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['Total Followers'].to_list()))))
            df2['Total Views'] = list(map(int, list(filter(lambda x: '.ads ' not in x, unclean['Total Views'].to_list()))))

            df1 = pd.concat([df2, df1], ignore_index=True)
    except:
        print(f"Stopped")
        
    #can sort by changing the title below from name to Total Views
    #default is rank
    return df1.sort_values('Rank').reset_index(drop=True) 

# df = read_html_thing()
# df.to_excel("General_Info3.xlsx")

# %%
# Time streamed is in Hours
# Avg viewers, Time streamed, hours watched, followers gained are for the last 30 days
#By default it is sorted by rank, which take into account on average concurrent viewers, followers, views and stream time for the last 30 days

df = pd.read_excel("General_Info.xlsx")

# for index in range(1, 4):
#     df1 = pd.read_excel(f"General_Info{index}.xlsx")
#     df = pd.concat([df1, df])
    
# # df.head()
# df.count()
# df.to_excel("General_info_final.xlsx")

# %%
df.Name = df.Name.replace('[^0-9a-zA-Z.,-/ ]', ' ', regex=True)
df = df[df.Name.str.isalnum()]
df = df[df.Name.str.strip() != '']
nameList = df.Name.to_list()
nameList
# Out:
# ['xQcOW',
#  'ibai',
#  'auronplay',
#  'Asmongold',
#  'Sapnap',
#  'Gaules',
#  'galaxyracerdxb',
#  'LEC',
#  'LCK',
#  'Fextralife',
#  'n3koglai',
#  'AdinRoss',
#  'Trainwreckstv',
#  'RocketLeague',
#  'Maximum',
#  'HasanAbi',
#  'casimito',
#  'tommyinnit',
#  'Mizkif',
#  'ROSHTEIN',
#  'ElMariana',
#  'juansguarnizo',
#  'Rubius',
#  'VALORANT',
#  'eliasn97',
#  'tarik',
#  'Elraenn',
#  'IlloJuan',
#  'NICKMERCS',
#  'RanbooLive',
#  'ElSpreen',
#  'LCS',
#  'aminematue',
#  'summit1g',
#  'WilburSoot',
#  'ImKaiCenat',
#  'elxokas',
#  'MontanaBlack88',
#  'CBLOL',
#  'Tubbo',
#  'buster',
#  'loltyler1',
#  'stylishnoob4',
#  'Faker',
#  'TheGrefg',
#  'deepins02',
#  'DreamLeague',
#  'TrashTastePodcast',
#  'TeamLiquid',
#  'aceu',
#  'Kamet0',
#  'Evelone192',
#  'buddha',
#  'CriticalRole',
#  'sodapoppin',
#  'TenZ',
#  'LVPes',
#  'Sykkuno',
#  'Elajjaz',
#  'egorkreed',
#  'QTCinderella',
#  'LyonWGFLive',
#  'AustinShow',
#  'Trymacs',
#  'bratishkinoff',
#  'HitPointOne',
#  'LIRIK',
#  'JojoHF',
#  'shroud',
#  'Clix',
#  'alanzoka',
#  'GRONKH',
#  'Rainbow6',
#  'BruceDropEmOff',
#  'EintrachtSpandau',
#  'RebirthzTV',
#  'Amar',
#  'Brawlhalla',
#  'MOONMOON',
#  'Squeezie',
#  'Zerkaa',
#  'Distortion2',
#  'BrawlStars',
#  'Nmplol',
#  'JLTomy',
#  's1mple',
#  'LPL',
#  'iiTzTimmy',
#  'moistcr1tikal',
#  'Ninja',
#  'Method',
#  'karlnetwork',
#  'ChristianVieriOfficial',
#  'Domingo',
#  'Emiru',
#  'Tumblurr',
#  'RiotGamesJP',
#  'EWROON',
#  'k4sen',
#  'Ponce',
#  'pokimane',
#  'Amouranth',
#  'Fortnite',
#  'Tfue',
#  'Gorgc',
#  'ArcSystemWorksU',
#  'GingiTV',
#  'CohhCarnage',
#  'Datto',
#  'k3soju',
#  'SilverName',
#  'SquadKoi',
#  'yourragegaming',
#  'Warframe',
#  'jschlatt',
#  'fuslie',
#  'ironmouse',
#  'gabepeixe',
#  'sapnapalt',
#  'SypherPK',
#  'Jasper7se',
#  'Doublelift',
#  'LVPes2',
#  'TheRealKnossi',
#  'PaymoneyWubby',
#  'Dhalucard',
#  'forsen',
#  'JesusAVGN',
#  'Topsonous',
#  'Thebausffs',
#  'Carreraaa',
#  'GMHikaru',
#  'EsfandTV',
#  'Baiano',
#  'TFBlade',
#  'Jerma985',
#  'Quin69',
#  'Crown',
#  'AdmiralBahroo',
#  'ZealsAmbitions',
#  'LVNDMARK',
#  'Gotaga',
#  'PENTA',
#  'daltoosh',
#  'Kyedae',
#  'CDawgVA',
#  'sinatraa',
#  'YoDa',
#  'ZanoXVII',
#  'DisguisedToast',
#  'Maya',
#  'twitchgaming',
#  'KendineMuzisyen',
#  'shongxbong',
#  'Caedrel',
#  'TwitchRivals',
#  'playapex',
#  'gafallen',
#  'AmazonMusic',
#  'AmazonMusicJP',
#  'Philza',
#  'Swagg',
#  'NickEh30',
#  'Mixwell',
#  'Jackeyy',
#  'Kyle',
#  'lolpacifictw',
#  'wtcN',
#  'Stray228',
#  'Recrent',
#  'ShahZaM',
#  'ShivFPS',
#  'WankilStudio',
#  'GamerBrother',
#  'Locklear',
#  'DeuceAce',
#  'Sardoche',
#  'GrenBaud',
#  'Robleis',
#  'JLAmaru',
#  'Hype',
#  'AntoineDaniel',
#  'chowh1',
#  'Gladd',
#  'knekro',
#  'sweetdreams',
#  'BENIJU03',
#  'RATIRL',
#  'PrimeLeague',
#  'paradeev1ch',
#  'bedbur',
#  'ATT',
#  'StRoGo',
#  'alexelcapo',
#  'elded',
#  'Unboxholics',
#  'Etoiles',
#  'SLAKUN10',
#  'kbsnews',
#  'imls',
#  's0mcs',
#  'abugoku9999',
#  'bysTaXx',
#  'itsaschoolnight',
#  'ZeratoR',
#  'Zoomaa',
#  'Whippy',
#  'shadowkekw',
#  'SPYGEA',
#  'mokrivskyi',
#  'Saintone',
#  'Subroza',
#  'Hiko',
#  'Northernlion',
#  'coscu',
#  'koreshzy',
#  'AnthonyZ',
#  'Aydan',
#  'RLEsports',
#  'MrSavage',
#  'Kitboga',
#  'TinaKitten',
#  'cxmmunity',
#  'featbeet',
#  '39daph',
#  'TubboLIVE',
#  'LITkillah',
#  'm0NESYoF',
#  'Scripe',
#  'vysotzky',
#  'ChilledChaos',
#  'karchez',
#  'burmaldaks',
#  'finalfantasyxiv',
#  'PietSmiet',
#  'GoodTimesWithScar',
#  'Jelty',
#  'veibae',
#  'midbeast',
#  'VooDooSh',
#  'lestream',
#  'boxbox',
#  'mistermv',
#  'AussieAntics',
#  'Taspio',
#  'f1ftynas',
#  'Rekkles',
#  'aXoZer',
#  'CORINNAKOPF',
#  'AgustinUnaplay8',
#  'HITBOXKING',
#  'AriGameplays',
#  'nyanners',
#  'Shaunz',
#  'EASPORTSFIFA',
#  'WHOPLOHOYPAREN',
#  'AsunaWEEB',
#  'Duke',
#  'eternalfiregg',
#  'cloakzy',
#  'GTAWiseGuy',
#  'Chess',
#  'vanseurope',
#  'LosPollosTV',
#  'Nihachu',
#  'Bonjwa',
#  'Otzdarva',
#  'TheRealMarzaa',
#  'Mastu',
#  'ybicanoooobov',
#  'YoungMulti',
#  'tenderlybae',
#  'relaxing234',
#  'mount',
#  'runthefutmarket',
#  'Stoopzz',
#  'MckyTV',
#  'BotezLive',
#  'stableronaldo',
#  'LuquEt4',
#  'TeePee',
#  'GRPZDC',
#  'pizfn',
#  'djurbor',
#  'TrueGeordie',
#  'BeyondTheSummit',
#  'HusKerrs',
#  'LenaGol0vach',
#  'parisplatynov',
#  'Solary',
#  'thedanirep',
#  'BlackDesertGame',
#  'JustCooman',
#  'Jankos',
#  'Fernanfloo',
#  'benjyfishy',
#  'Shylily',
#  'WARDELL',
#  'RduLIVE',
#  'tvandeR',
#  'flashingbeams',
#  'WestCOL',
#  'Coreano',
#  'ElmiilloR',
#  'RiotGamesTurkish',
#  'BlackTwitchUK',
#  'AdmiralBulldog',
#  'Gumayusi',
#  'RDCgaming',
#  'Xari',
#  'SmiteGame',
#  'Silent',
#  'ElChiringuitoTV',
#  'btssmash',
#  'valorantesports4',
#  'QuarterJade',
#  'ScreaM',
#  'HoneyMad',
#  'ELoTRiX',
#  'tioorochitwitch',
#  'Dkayed',
#  'Werlyb',
#  'Jinnytty',
#  'AyeZee',
#  'AlphaCast',
#  'Elwind',
#  'Symfuhny',
#  'mazellovvv',
#  'Kaydop',
#  'Carola',
#  'ramzes',
#  'landonorris',
#  'TisiSchubech',
#  'PROD',
#  'NimuVT',
#  'xRohat',
#  'TeeGrizzley',
#  'richwcampbell',
#  'Rezo',
#  'pokelawls',
#  'Blaustoise',
#  'Japczan',
#  'GothamChess',
#  'agustin51',
#  'GronkhTV',
#  'dwjft',
#  'IWDominate',
#  'Pestily',
#  'Yassuo',
#  'Punz',
#  'Freneh',
#  'pqueen',
#  'SmallAnt',
#  'maxim',
#  'Magic',
#  'Nissaxter',
#  'koil',
#  'singsing',
#  'sumayyl',
#  'Diegosaurs',
#  'weegaso',
#  'NiklasWilson',
#  'willneff',
#  'FrankDimes',
#  'RocketBaguette',
#  'keznit1',
#  'omie',
#  'ZilverK',
#  'RoyalPhunk',
#  'yointerneto',
#  'xth0rek',
#  'IamCristinini',
#  'BarbarousKing',
#  'dota2mc',
#  'Nadeshot',
#  'dogdog',
#  'Jolavanille',
#  'DarioMocciaTwitch',
#  'Sweatcicle',
#  'SonySanDiegoStudio',
#  'Preachlfw',
#  'DiazBiffle',
#  'qojqva',
#  'Nisqyy',
#  'est3ps',
#  'nba2k',
#  'Flight23white',
#  'OMEN',
#  'DreadzTV',
#  'Gigguk',
#  'spkclb',
#  'LuluLuvely',
#  'ClintStevens',
#  'JaggerPrincesa',
#  'JackManifoldTV',
#  'shxtou',
#  'ClassyBeef',
#  'lilypichu',
#  'NOBRU',
#  'OReiTroll',
#  'QuickyBaby',
#  'Wirtual',
#  'LLA',
#  'Xposed',
#  'Alinity',
#  'Faide',
#  'Perxitaa',
#  'BastiGHG',
#  'ekatze007',
#  'Rogue',
#  'ceh9',
#  'Agraelus',
#  'Waolol1',
#  'follentass',
#  'Giggand',
#  'GernaderJake',
#  'ZLOYn',
#  'Popo',
#  'RevedTV',
#  'Drututt',
#  'Myth',
#  'diariooleok',
#  'JrokezFTW',
#  'SummonersInnLive',
#  'melharucos',
#  'DuendePablo',
#  'LukiSteve',
#  'ploo',
#  'SolaryHS',
#  'SidneyEweka',
#  'blackelespanolito',
#  'POW3Rtv',
#  'Naowh',
#  'LobosJr',
#  'jakenbakeLIVE',
#  'aimsey',
#  'kkatamina',
#  'snlive1',
#  'BOOMBURAPA',
#  'Deansocool',
#  'R6esportsBR',
#  'Tectone',
#  'Ranger',
#  'chiringuitodejug3',
#  'StRoGo1337',
#  'Papaplatte',
#  'supertf',
#  'PWRDEsports1',
#  'TolkinLoL',
#  'guit88man',
#  'Staryuuki',
#  'FolagorLives',
#  'UberHaxorNova',
#  'Josedeodo',
#  'AvoidingThePuddle',
#  'adolfz',
#  'Shotz',
#  'Mongraal',
#  'VonDice',
#  'Tonton',
#  'cyr',
#  'drb7h',
#  'Djilsi',
#  'Altair',
#  'Grendy',
#  'pisicela',
#  'Aztecross',
#  'CollisionSmash',
#  'superjj102',
#  'goncho',
#  'Sommerset',
#  'Staiy',
#  'GENSYXA',
#  'kamikpro',
#  'dopa24',
#  'BadBoyHalo',
#  'chusommontero',
#  'Ssaab',
#  'Opat04',
#  'LatinUp',
#  'Homyatol',
#  'akyuliych',
#  'ilGabbrone',
#  'iLame',
#  'McconnellRet',
#  'erobb221',
#  'snuffy',
#  'sacy',
#  'BigBossBoze',
#  'JeanMassiet',
#  'goblin064',
#  'sasatikk',
#  'RTGame',
#  'Shotzzy',
#  'TheDrossRotzank',
#  'Limmy',
#  'CodeMiko',
#  'berleezy',
#  'SMii7Y',
#  'Andypsx',
#  'agurin',
#  'Insym',
#  'TodosgamersFreeFire',
#  'ungespielt',
#  'Pieface23',
#  'biroPJL',
#  'roflgator',
#  'Mynthos',
#  'robcdee',
#  'SkyrrozTV',
#  'samueletienne',
#  'MuTeX',
#  'lilsimsie',
#  'dilblin',
#  'Atrioc',
#  'Moonryde',
#  'Mithrain',
#  'AmateurBOHNE',
#  'LCKCL',
#  'TwitchSports',
#  'Smoke',
#  'masondota2',
#  'druski',
#  'DatModz',
#  'Ac7ionMan',
#  'PlayHearthstone',
#  'Masayoshi',
#  'icebergdoto',
#  'unicornio',
#  'RTAinJapan',
#  'DougDougW',
#  'Wolfabelle',
#  'TangoTek',
#  'gerardromero',
#  'jukes',
#  'BobRoss',
#  'NiceWigg',
#  'momoladinastia',
#  'dannyaarons',
#  'skill4ltu',
#  'impulseSV',
#  'uccleague2',
#  'awesamdude',
#  'Manyrin',
#  'Jacob4TV',
#  'Greekgodx',
#  'Sequisha',
#  'liminhag0d',
#  'DoktorFroid',
#  'BigEx',
#  'Zentreya',
#  'Zoil',
#  'Vinesauce',
#  'aspaszin',
#  'Shlorox',
#  'uhSnow',
#  'yEojLawStreams',
#  'BlackUFA',
#  'boyMinORu',
#  'WIGFrance',
#  'Thijs',
#  'Nightblue3',
#  'ChristianMartin03',
#  'brkk',
#  'DannehTV',
#  'Daxak',
#  'fnxLNTC',
#  'alexdieci',
#  'TheRunningManZ',
#  'Annoying',
#  'k4t4n4',
#  'Alexclick',
#  'xmerghani',
#  'BTMC',
#  'G4TV',
#  'CDNThe3rd',
#  'Bugha',
#  'AnniTheDuck',
#  'Scarra',
#  'edizderbreite',
#  'LaureBV',
#  'Mande',
#  'elwycco',
#  'imaqtpie',
#  'skippypoppin',
#  'Pyromancer',
#  'FarfadoxVEVO',
#  'HLTVorg',
#  'yejuniverse',
#  'IJenz',
#  'TrilluXe',
#  'Tomato',
#  'itsRyanHiga',
#  'Enviosity',
#  'UniRocketeers',
#  'Selly55',
#  'kyo1984123',
#  'SolaryFortnite',
#  'Steelmage',
#  'Simply',
#  'REVENANT',
#  'Rakin',
#  'JoeWo',
#  'holyphoenix',
#  'KhaosAdam',
#  'SoyMotor',
#  'Eray',
#  'gorilon',
#  'defantediogo',
#  'miniminter',
#  'dafran',
#  'JUJALAG',
#  'x2Twins',
#  'Keria',
#  'MONSTERSANDEXPLOSIONS',
#  'ExatlonEstadosUnidos2022',
#  'WELOVEGAMES',
#  'des0ut',
#  'Hayashii',
#  'juliusave',
#  'IsVolcano',
#  'PAGO3',
#  'derdunkleparabelritter',
#  'DessT3',
#  'PlayStation',
#  'Enkk',
#  'manuellsen4545',
#  'Kiyoon',
#  'GeminiTay',
#  'TheStockGuy',
#  'RollingStone',
#  'Alexby11',
#  'MartinCirioOk',
#  'jbzzed',
#  'Stewie2K',
#  'breakingitaly',
#  'Kubx',
#  'hakumai',
#  'BoxyFresh',
#  'IzakOOO',
#  'Destiny',
#  'DaigoTheBeasTV',
#  'davooxeneize',
#  'balelalive',
#  'SharonQueen',
#  'EnzoKnol',
#  'Sacriel',
#  'FiReSPORTStv',
#  'TGLTN',
#  'Leynainu',
#  'NeutrooYT',
#  'Flavorr',
#  'Mathil1',
#  'Vadeal',
#  'UNLOSTV',
#  'WorldofTanks',
#  'arielhugo3',
#  'Sintica',
#  'MarcoMerrino',
#  'EAMaddenNFL',
#  'chocoTaco',
#  'ZakvielChannel',
#  'TpaBoMaH',
#  'Euriece',
#  'resttpowered',
#  'MenosTrece',
#  'skgaming',
#  'Faiar',
#  'luquitarodriguez',
#  'Alderiate',
#  'cNed',
#  'TheRelixChannel',
#  'projektmelody',
#  'FifaTargrean',
#  'sukidingels',
#  'docm77LIVE',
#  'SkipNhO',
#  'frametamer666',
#  'chihiro2434',
#  'FaridBangChannel',
#  'Peeve',
#  'Becca',
#  'seoldam99',
#  'frttt',
#  'Luken',
#  'ReventXz',
#  'nAts',
#  'Th3Antonio',
#  'Sco',
#  'TANZVERBOT',
#  'robinsongz',
#  'JimmyHere',
#  'Luzu',
#  'jinjulin',
#  'Mylonzete',
#  'EmmaLangevin',
#  'Loeya',
#  'OWOWOWOWOWOOW0',
#  'iskall85',
#  'Dekarldent',
#  'oestagiario',
#  'AversionDE',
#  'valorantesports3',
#  'CasinoDaddy',
#  'chesscomlive',
#  'DeliciousMilkGG',
#  'Zizaran',
#  'Lacari',
#  'after6junction',
#  'julien',
#  'SovietWomble',
#  'fl0m',
#  'sashagrey',
#  'bananabrea',
#  'TcK10',
#  'rubenmartinweb',
#  'Mortdog',
#  'facudiazt',
#  'elchiringuitodejug1',
#  'eldemente',
#  'BigDaddy',
#  'Dropped',
#  'Fruktozka',
#  'Linkus7',
#  'SnikWins',
#  'Hungrybox',
#  'xCry',
#  'Giantwaffle',
#  'LeBouseuh',
#  'RuWarface',
#  'Gosu',
#  'RoozWorld',
#  'Timmac',
#  'nooneboss',
#  'EliteDangerous',
#  'WorldofWarships',
#  'r00t9r',
#  'Terracid',
#  'SpectateTyler1',
#  'drakeoffc',
#  'Nympea',
#  'LOLITOFDEZ',
#  'Sologesang',
#  'BlitzStream',
#  'Herdyn',
#  'lajefaok',
#  'GamesDoneQuick',
#  'BurkeBlack',
#  'primevideoes',
#  'Aurateur',
#  'Genburten',
#  'jokniyodre',
#  'akagreenn',
#  'ALOHADANCETV',
#  'Silvervale',
#  'Purpled',
#  'taxi2g',
#  'Skermz',
#  'Bruninzor',
#  'katoo',
#  'Aa9skillz',
#  'spoilkingoutlook',
#  'CanBroke',
#  'Tylerootd',
#  'Olsior',
#  'LGLOYAL',
#  'WeAreTheVR',
#  'BLASTPremier',
#  'GAECHKATM',
#  'AQUINOby2002',
#  'SpartaTheOriginal',
#  'scoped',
#  'flamengoaovivo1',
#  'Evangelion0',
#  'Zaelia',
#  'okyyy',
#  'FPSThailand',
#  'stormen',
#  'neeko',
#  'Nikof',
#  'CALCIOBERLIN',
#  'LinusTech',
#  'Felps',
#  '8cho',
#  'anabancr',
#  'snoodyboo',
#  'kennyS',
#  'Crystalst',
#  'ernesBarbeQ',
#  'AmazonMusicES',
#  'HutchMF',
#  'yuuechka',
#  'pijack11',
#  'CookSux',
#  'crokeyz',
#  'INSCOPE21TV',
#  'Calebhart42',
#  'sneakylol',
#  'AmazonMusicBR',
#  '1PVCS',
#  'LCO',
#  'LaSapaaaaa',
#  'Yotobi',
#  'Teuf',
#  'sheenviktor',
#  'SPONTENT',
#  'tteuw',
#  'RevolAimar',
#  'Grimmmz',
#  'MOTHER3rd',
#  'Mayichi',
#  'Nix',
#  'SmashFactorGaming',
#  'PUBGThailandOfficial',
#  'evaanna',
#  'zai',
#  'Akademiks',
#  'kyootbot',
#  'darrinebron',
#  'Deadlyslob',
#  'NymN',
#  'LACOBRAAA',
#  'EFEUYGAC',
#  'GrandPOObear',
#  'stevewillsendit',
#  'Eret',
#  'Saruei',
#  'ibabyrainbow',
#  'YassEncore',
#  'SunBaconRelaxer',
#  'Slimecicle',
#  'Spursito',
#  'Maghla',
#  'Cava111',
#  'Smzinho',
#  'paivinha29',
#  'TNTSportsBr',
#  'Mandzio',
#  'Zy0xxx',
#  'mikelabelle',
#  'GUACAMOLEMOLLY',
#  'Grimm',
#  'Marzzzzy',
#  'Doigby',
#  'watchmeblink',
#  'LetsGameItOut',
#  'ouahleouff88',
#  'natalan',
#  'DanucD',
#  'Fundy',
#  'Snip3down',
#  'DansGaming',
#  'Nikolarn',
#  'Zemie',
#  'polispol1',
#  'dkincc',
#  'Chica',
#  'BRAT',
#  'bigdumbgaming',
#  'getFlakked',
#  'BreitenVonBerg',
#  'IGN',
#  'scruffoftheneck',
#  'eusheviii2k',
#  'BigIraq',
#  'Agustabell212',
#  'Lazvell',
#  'Academy',
#  'yamatonjp',
#  'RealzBlueWater',
#  'Twayko',
#  'JOEYKAOTYK',
#  'KAANFLIX',
#  'Xisuma',
#  'Pompeyo4',
#  'Serpentgameplay',
#  'Putupau',
#  'Clemovitch',
#  'aleks',
#  'Fragnance',
#  'aroyitt',
#  'maplesports',
#  'JeelTV',
#  'ash',
#  'TheChief1114',
#  'Shoopi',
#  'FollowGrubby',
#  'Lost',
#  'KayaYanar',
#  'HOLLYWOOD285',
#  'tarzaned',
#  'MarkitoNavaja',
#  'Diables',
#  'halliezhmdz',
#  'Stepanio666',
#  'mlodziutki7',
#  'HarukaKaribu',
#  'ConnorEatsPants',
#  'FantaBobShow',
#  'migbizzy',
#  'Apricot',
#  'drawfeeshow',
#  'noctAQ',
#  'redbyrd',
#  'LittleBigWhale',
#  'RubyTrue',
#  'jessirocks',
#  'zwebackhd',
#  'Leopard',
#  'HoneyPuu',
#  'Payo',
#  'KSPKSP',
#  'LexVeldhuis',
#  'ElcanaldeJoaco',
#  'iWe11y',
#  'TraYtoNlol',
#  'MasterSnakou',
#  'Brizz94',
#  'Ampeterby7',
#  'StarWraith',
#  'Lasqa',
#  'superleague',
#  'LeekBeats',
#  'lubatv',
#  'iNoiizY',
#  'BruceGrannec',
#  'Scurrows',
#  'KarmikKoala',
#  'LasVegasVP',
#  'cheatbanned',
#  'Murda',
#  'Bigezmoge',
#  'mailand',
#  'OhTofu',
#  'sizophren',
#  'WagamamaTV',
#  'ItsJSTN']

# %%
# namesPD=pd.DataFrame()
# namesPD=df.Name.to_list()
# namesPD
# namesPD.columns = ['login']
# namesPD.to_excel("New_Names.xlsx")
# names = df.Name.to_list()
# len(names)

# %%
import math

Client_ID = 'eceifr3vixcltzyw8g4f9yeiv0rpy8'
Secret  = 'vxt336xddant33lagzkvpwo5n5ibw5'

def urlSearch(URL, nameList, count, paramStr):
    
    for x in nameList[100*(count-1) : (100*count)]:
        if URL[-1] == '?':
            URL = f"{URL}{paramStr}={x}"
        else:
            URL =  f"{URL}&{paramStr}={x}"

    return URL

def Check(endpoint, paramStr, nameList, countsOf100):
    
    autCallJson = requests.post(url='https://id.twitch.tv/oauth2/token', 
                                params={'client_id': Client_ID,
                                        'client_secret': Secret,
                                        'grant_type': 'client_credentials'}).json()
    
    head = {'Client-ID' : Client_ID,
            'Authorization' :  "Bearer " + autCallJson['access_token']}
    
    df = pd.DataFrame()

    urlEndpoint = f"https://api.twitch.tv/helix/{endpoint}?"
    
    for index in range(1, countsOf100+1):
        rJson = requests.get(urlSearch(urlEndpoint, 
                                       nameList, 
                                       index, 
                                       paramStr), 
                         headers = head).json()
        df = pd.concat([df, pd.json_normalize(rJson['data'])], 
                       ignore_index=True)

    return df

def addCurrentHrStreams(nameList, noOfStreamersFromList):
    
    countOf100 = int(math.ceil(noOfStreamersFromList / 100.0))
    
    df1 = Check('streams', 'user_login', nameList, countOf100)
    df1 = df1.drop(columns=['game_id', 'thumbnail_url', 'tag_ids'])
    df1['time_extracted'] = datetime.now()
    
    return df1
    
def mainFunction(path, durationInHours=1, nameList=nameList, topNoOfStreamers=1000):
    
    if os.path.exists(path):
        final = pd.read_excel(path, index_col=0)
    else:
        final = pd.DataFrame()
    
    for x in tqdm(range(durationInHours)):
        df1 = addCurrentHrStreams(nameList, topNoOfStreamers)
        df1.index = df1.index + 1
        final = pd.concat([final, df1], ignore_index=False)
        final.to_excel(path)
        time.sleep(3590)

mainFunction("Live_Stream_Data.xlsx", 8)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 8/8 [7:59:09<00:00, 3593.71s/it]

# %%
# https://api.twitch.tv/helix/subscriptions
# GET https://api.twitch.tv/helix/users/follows?to_id=<user ID>

# df3 = namesPD.merge(df, how='left', indicator=True)

# df3 = df3[df3['_merge'] == 'left_only']
# df3


# # df3.count()

# df1 = Check()

# # df1 = df1.drop(columns=['game_id', 'thumbnail_url', 'tag_ids'])

# df1['time_extracted'] = datetime.now()

# df1


# import json

# f = open ('jsonviewer.json', "r")
# ff = json.load(f)

# dffff = pd.DataFrame()

# # print(ff['data'][0])
# for x in ff['data']:
#     dffff = pd.concat([dffff, pd.DataFrame(x)])
    
# dffff.head()

# %%
# def urlSearch(count):
    
#     URL = 'https://api.twitch.tv/helix/streams?'
    
#     for x in nameList[100*(count-1) : (100*count)+1]:
#         if URL[-1] == '?':
#             URL = URL + 'user_login=' + x
#         else:
#             URL = URL + '&user_login=' + x
            
            
#     return URL
        
# authURL = 'https://id.twitch.tv/oauth2/token'
# Client_ID = 'eceifr3vixcltzyw8g4f9yeiv0rpy8'
# Secret  = 'vxt336xddant33lagzkvpwo5n5ibw5'

# AutParams = {'client_id': Client_ID,
#              'client_secret': Secret,
#              'grant_type': 'client_credentials'
#              }


# def Check():
#     AutCall = requests.post(url=authURL, params=AutParams) 
#     access_token = AutCall.json()['access_token']

#     head = {
#     'Client-ID' : Client_ID,
#     'Authorization' :  "Bearer " + access_token
#     }
    
#     df = pd.DataFrame()

#     for x in range(1, 21):
#         r = requests.get(urlSearch(x), headers =  head).json()
        
#         df = pd.concat([df, pd.json_normalize(r['data'])], ignore_index=True)
        
           
#     return df


# final = pd.DataFrame()

# count = 0


# def hourlyFunction(final, count):
#     df1 = Check()
#     df1 = df1.drop(columns=['game_id', 'thumbnail_url', 'tag_ids'])
#     df1['time_extracted'] = datetime.now()
#     time.sleep(3590)
#     final = pd.concat([final, df1], ignore_index=False)
#     count = count+1
    
#     if count <= 12:
#         hourlyFunction(final, count)
#     else:
#         final.index = final.index + 1
#         final.to_excel("Live_Stream_Data.xlsx")
        
# hourlyFunction(final, count)

# %%
# def urlSearch(count):
    
#     URL = 'https://api.twitch.tv/helix/users?'
    

#     for x in names[100*(count-1)+1 : (100*count)+1]:
#         if URL[-1] == '?':
#             URL = URL + 'login=' + x
#         else:
#             URL = URL + '&login=' + x
            
    
            
#     return URL
        
# authURL = 'https://id.twitch.tv/oauth2/token'
# Client_ID = 'eceifr3vixcltzyw8g4f9yeiv0rpy8'
# Secret  = 'vxt336xddant33lagzkvpwo5n5ibw5'

# AutParams = {'client_id': Client_ID,
#              'client_secret': Secret,
#              'grant_type': 'client_credentials'
#              }


# def Check():
#     AutCall = requests.post(url=authURL, params=AutParams) 
#     access_token = AutCall.json()['access_token']

#     head = {
#     'Client-ID' : Client_ID,
#     'Authorization' :  "Bearer " + access_token
#     }
    
#     df = pd.DataFrame()

#     for x in range(1, 11):
#         r = requests.get(urlSearch(x), headers = head).json()
#         if r['data']: 
#             df = pd.concat([df, pd.json_normalize(r['data'])],ignore_index=True)
#             df.index = df.index + 1
    
#     return df

# df = Check().drop(columns=['profile_image_url', 'offline_image_url', 'type'])
# df = df.groupby('id').filter(lambda x : x['id'].shape[0] < 2)

# df

# df.to_excel("All_1000_users_general_information.xlsx")

# %%
# idList = df.id.to_list()

# def urlSearch(id):

#     URL = 'https://api.twitch.tv/helix/users/follows?to_id='+id
            
#     return URL
        
#     authURL = 'https://id.twitch.tv/oauth2/token'
#     Client_ID = 'eceifr3vixcltzyw8g4f9yeiv0rpy8'
#     Secret  = 'vxt336xddant33lagzkvpwo5n5ibw5'

#     AutParams = {'client_id': Client_ID,
#                  'client_secret': Secret,
#                  'grant_type': 'client_credentials'
#                  }

# def Check():
#     AutCall = requests.post(url=authURL, params=AutParams) 
#     access_token = AutCall.json()['access_token']

#     head = {
#     'Client-ID' : Client_ID,
#     'Authorization' :  "Bearer " + access_token
#     }
    
#     df = pd.DataFrame()

#     for x in idList:
#         r = requests.get(urlSearch(x), headers = head).json()
#         df = pd.concat([df, pd.DataFrame({'to': [r['data'][0]['to_name']], 'total':[r['total']]})],ignore_index=True)
#         df.index = df.index + 1

#     return df


# df2 = Check().drop_duplicates()

# df2.to_excel("Streamers_follower_count.xlsx")

# %%
# def read_list(file):
#     channel_list = []
#     with open(file, 'r', encoding='utf-8') as filehandler:
#         channel_list = filehandler.readlines()
#     channel_list = [streamer[:-1] for streamer in channel_list]
#     return channel_list

# names = read_list("names.txt")

# namesPD = pd.DataFrame(names)

# namesPD = namesPD[1:] #take the data less the header row
# namesPD.columns = ['login'] #set the header row as the df header

# namesPD = namesPD.sort_values(by=['login'])

# namesPD.login = namesPD.login.apply(lambda x: x.lower())

# namesPD
